# %% [markdown]
# # <center><a href='https://notebook.basthon.fr/?from=https://raw.githubusercontent.com/lchalmain/mp2i-info/main/tp1-2_types_fonctions.ipynb?kernel=ocaml'>TP 1.2 : Types et fonctions <img src=https://framagit.org/uploads/-/system/project/avatar/55763/basthon_shadow.png width=100></a></center>
#
# <center><h1 style = "color:red"> Corrigé </h1></center>

# %% [markdown]
#  **<span style = "color:orange">Important :</span>** lorsque vous définissez une fonction, pensez à la tester sur un jeu de valeurs !

# %% [markdown]
# ## Signature
#
# **<p style = "color:purple">Exercice :</p>**
#  1. Définir une fonction `double : int -> int` qui renvoie le double de la valeur en argument.
#  1. Deviner avant de vérifier la valeur renvoyée par l'expression suivante :
#  ```ocaml
#  let h x = double x  + 1 in
#  h 3;;
#  ```

# %%
let double x = 2 * x;;
# Out:
# val double : int -> int = <fun>

# %%
let h x = double x + 1 in
h 3;;
# Out:
# - : int = 7

# %% [markdown]
#  **<p style = "color:purple">Exercice :</p>**
#  1. Vérifier la signature de la fonction `sqrt` (racine carée) déjà définie en Ocaml.
#  2. Deviner la signature puis définir la fonction $f : x\longmapsto \dfrac1{\sqrt{1+x^2}}$.

# %%
sqrt;;
# Out:
# - : float -> float = <fun>

# %%
let f x = 1. /. (sqrt (1. +. x ** 2.));;
# Out:
# val f : float -> float = <fun>

# %%
assert (f 0. = 1.)
# Out:
# - : unit = ()

# %% [markdown]
#  **<p style = "color:purple">Exercice :</p>**
#  1. Devinez la signature des fonctions suivantes et vérifier avec OCaml :
# ```ocaml
# let f x y = x**y;;
# ```
# ```ocaml
# let g x y = x (y + 1);;
# ```
# ```ocaml
# let h x y z = x (3. *. (y z)) + 1;;
# ```
# 1. Tester ces fonctions sur des arguments de votre choix.

# %%
let f x y = x**y;;
# Out:
# val f : float -> float -> float = <fun>

# %%
let g x y = x (y + 1);;
# Out:
# val g : (int -> 'a) -> int -> 'a = <fun>

# %%
let h x y z = x (3. *. (y z)) + 1;;
# Out:
# val h : (float -> int) -> ('a -> float) -> 'a -> int = <fun>

# %%
f 3. 4.;;
# Out:
# - : float = 81.

# %%
g double 6;;
# Out:
# - : int = 14

# %%
h int_of_float sqrt 2.0;;
# Out:
# - : int = 5

# %% [markdown]
#  **<p style = "color:purple">Exercice :</p>**
#
#  1. Écrire une fonction `max` qui renvoie le maximum de deux arguments.
#  1. Observer la signature de la fonction. Déterminer trois types possibles pour `'a`.

# %%
let max x y =
    if x > y then x
    else y
;;
# Out:
# val max : 'a -> 'a -> 'a = <fun>

# %%
assert (max 2 3 = 3);
assert (max 5. (-1.) = 5.);
assert (max "mot" "chaine" = "mot")
# Out:
# - : unit = ()

# %% [markdown]
# La fonction `max` est définie pour des arguments appartenants à un ensemble totalement ordonné. Ces arguments peuvent être de type `int`, `float` ou même `string`(ordre lexicographique).

# %% [markdown]
#  **<p style = "color:purple">Exercice :</p>**
#  Définir en OCaml la fonction $\tanh : x \longmapsto \dfrac{e^x - e^{-x}}{e^x + e^{-x}}$ en utilisant un seul appel à la fonction `exp : float -> float` de OCaml.

# %%
let tanh x = let e = exp x in
    (e -. 1. /. e) /. (e +. 1. /. e)
;;
# Out:
# val tanh : float -> float = <fun>

# %%
assert (tanh 0. = 0.)
# Out:
# - : unit = ()

# %% [markdown]
# ### Géométrie
#
# Le type `float*float` désigne un couple de flottants, et peut représenter un point `p` dans $\mathbb{R}^2$.
#
# On peut récupérer les coordonnées de `p` avec la déclaration `let x, y = p` . Par exemple :

# %%
let p = (2.1, 3.7) in (* exemple de point *)
let x, y = p in (* récupération des coordonnées *)
x;; (* affichage de x *)
# Out:
# - : float = 2.1

# %% [markdown]
#  **<p style = "color:purple">Exercice :</p>**
#  Écrire une fonction `aire_boule : float -> float` telle que `aire_boule r` renvoie l'aire d'une boule (disque en dimension 3) de rayon `r`, c'est à dire $\frac{4 \pi r^3}{3}$. On pourra utiliser `Float.pi`.

# %%
let aire_boule r = Float.pi *. r ** 2.;;
# Out:
# val aire_boule : float -> float = <fun>

# %%
assert ((aire_boule 1.) -. Float.pi < 0.00001);
assert ((aire_boule 2.) -. 4.*.Float.pi < 0.00001)
# Out:
# - : unit = ()

# %% [markdown]
#  **<p style = "color:purple">Exercice :</p>**
#  1. Écrire une fonction `distance : float*float -> float*float -> float` telle que `distance p1 p2` renvoie la distance euclidienne entre les points `p1` et `p2`.
# 1. Vérifier que la distance entre $(0, 0)$ et $(1, 1)$ est (approximativement) $\sqrt{2}$.

# %%
let distance p1 p2 = let (x1, y1) = p1 and (x2, y2) = p2 in
    sqrt ( (x2 -. x1)**2. +. (y2 -. y1)**2. )
;;
# Out:
# val distance : float * float -> float * float -> float = <fun>

# %%
assert ( (distance (0., 0.) (1., 1.)) -. (sqrt 2.) < 0.00001)
# Out:
# - : unit = ()

# %% [markdown]
#  **<p style = "color:purple">Exercice :</p>**
#  Écrire une fonction `polaire : float*float -> float*float` qui, étant donné les coordonnées polaires $(r, \theta)$ d'un point, renvoie ses coordonnées cartésiennes $(x, y)$. On rappelle que $x = r\cos(\theta)$ et $y = r\sin(\theta)$. On pourra utiliser `cos` et `sin` en OCaml.

# %%
let polaire (r, theta) =
    (r *. (cos theta), r *. (sin theta))
;;
# Out:
# val polaire : float * float -> float * float = <fun>

# %% [markdown]
# En fait, on peut déconstruire le tuple en argument dans la fonction comme dans l'exercice précédent, ou bien comme ici le faire directement dans l'argument.

# %% [markdown]
#  **<p style = "color:purple">Exercice :</p>**
#  Écrire une fonction `milieu : float*float -> float*float -> float*float` telle que `milieu p1 p2` renvoie le milieu du segment d'extrémités `p1` et `p2`.

# %%
let milieu (x1, y1) (x2, y2) = (x1 +. x2) /. 2. , (y1 +. y2) /. 2.;;
# Out:
# val milieu : float * float -> float * float -> float * float = <fun>

# %%
assert (milieu (1., 5.) (-3., 7.) = (-1., 6.))
# Out:
# - : unit = ()

# %% [markdown]
#  **<p style = "color:purple">Exercice :</p>**
#  Écrire une fonction `orthogonaux : int*int -> int*int -> bool` qui détermine si deux vecteurs sont orthogonaux ou non.

# %%
let orthogonaux u1 u2 = let (x1, y1) = u1 and (x2, y2) = u2 in
    x1 *. x2 +. y1 *. y2 = 0.
;;
# Out:
# val orthogonaux : float * float -> float * float -> bool = <fun>

# %%
assert (orthogonaux (3., 4.) (4., -3.));
assert (not (orthogonaux (5., -2.) (5., 8.)) );;
# Out:
# - : unit = ()

# %% [markdown]
# ## Références
#
#  **<p style = "color:purple">Exercice :</p>**
#  1. Prédire la signature de la fonction `swap` qui échange les valeurs de deux références.
#  2. Définir la fonction swap.

# %%
let swap x y = let z = !x in
    x := !y;
    y := z
;;
# Out:
# val swap : 'a ref -> 'a ref -> unit = <fun>

# %%
let x, y = ref 4, ref 8;;
swap x y;;
!x, !y;;
# Out:
# val x : int ref = {contents = 4}
# val y : int ref = {contents = 8}
# - : unit = ()
# - : int * int = (8, 4)
